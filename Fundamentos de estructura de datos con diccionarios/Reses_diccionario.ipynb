# %%
d1 = {'r01': ['m', 200, 400], 'r02': ['h', 100, 200], 'r03': ['m', 125, 250], 'r04': ['h', 145, 480],
'r05': ['m', 170, 480], 'r06': ['h', 350, 600], 'r07': ['m', 175, 475], 'r08': ['h', 180, 460], 'r09': ['m', 170, 468],
'r10': ['h', 179, 479], 'r11': ['h', 180, 580], 'r12': ['h', 180, 470], 'r13': ['m', 195, 460], 'r14': ['h', 190, 480],
'r15': ['h', 185, 195], 'manchas': ['m', 172, 385], 'negra': ['h', 210, 470], 'chispas': ['m', 240, 478], 
'estrella': ['h', 190, 400], 'cachona': ['h', 200, 480], 'lulu': ['h', 183, 481], 'pepe': ['m', 170, 450],
'federico': ['m', 188, 482], 'copito': ['m', 189, 481], 'dalmata': ['h', 175, 477]}

suma1=0 # suma de pesos iniciales de hembra
suma2=0 # suma de pesos finales de hembra
suma3=0 # suma de pesos iniciales de macho
suma4=0 #suma de pesos finales de macho
suma5=0 # suma de los pesos iniciales 
suma6=0 # suma de los pesos finales 
count1=0 # contador de las hembras 
count2=0 # contador de los machos 

for i in d1:
    if d1[i][0]== "h":
        suma1= suma1 + d1[i][1] # suma los pesos iniciales de la hembras 
        suma2= suma2 + d1[i][2] # suma los pesos finales de las hembras
        count1= count1 + 1 
    if d1[i][0] == "m":
        suma3= suma3 + d1[i][1] # suma los pesos iniciales de los machos
        suma4= suma4 + d1[i][2] # suma lños pesos finales de los machos 
        count2 = count2 + 1
    suma5= suma5 + d1[i][1] # suma los pesos iniciales en general
    suma6= suma6 + d1[i][2] # suma los pesos finales en general
    
prom1=suma1 / count1 # promedio de los pesos iniciales de las hembras 
prom2= suma2/ count1 # promedio de los pesos finales de las hembras     
prom3= suma3 / count2 # promedio de los pesos iniciales de los machos 
prom4= suma4/ count2 # promedio de los pesos finales de los machos 
prom5= suma5/ len(d1) # promedio de los pesos iniciales en general
prom6= suma6/len (d1) # promedio de los pesos finales en general
    
print(f"el peso promedio inicial de las hembras es de {prom1}, \nel peso promedio inicial de los machos es de {prom3}, \ny el promedio de los pesos en general es de {prom5}")
print()
print(f" el peso promedio final de las hembras es de {prom2}, \nel peso promedio final de los machos es de {prom4}, \ny el promedio de los pesos finales en general es de {prom6}")
print()    
nombres= []

for i in d1:
    if d1[i][2] < prom6:
        nombre1=i
        nombres.append(nombre1)

print (" las reces que presentan un peso inferior al peso promedio al peso de todo el lote del ganado son: ",nombres)
print()
mayor=0

for i in d1:
    aumento=((d1[i][2]-d1[i][1])/d1[i][1])*100
    nombres2=[]
    
if d1[i][1] > mayor:
    mayor=d1[i][1]
    nombre2=i
    nombres2.append(nombre2)
    
print ("la res con mayor porcentaje de aumento de peso es: ",nombres2)
print()
resmayor=0

for i in d1:
    if d1[i][2] >= 480:
        resmayor= resmayor + 1
        efectividad=(resmayor/25) * 100
        
print (" la efectividad es: ",efectividad)
print()
for i in d1.keys():
    print(i, end = "    ")
# Out:
# el peso promedio inicial de las hembras es de 189.07142857142858,
# el peso promedio inicial de los machos es de 181.27272727272728,
# y el promedio de los pesos en general es de 185.64
#
#  el peso promedio final de las hembras es de 446.57142857142856,
# el peso promedio final de los machos es de 437.1818181818182,
# y el promedio de los pesos finales en general es de 442.44
#
#  las reces que presentan un peso inferior al peso promedio al peso de todo el lote del ganado son:  ['r01', 'r02', 'r03', 'r15', 'manchas', 'estrella']
#
# la res con mayor porcentaje de aumento de peso es:  ['dalmata']
#
#  la efectividad es:  36.0
#
# r01    r02    r03    r04    r05    r06    r07    r08    r09    r10    r11    r12    r13    r14    r15    manchas    negra    chispas    estrella    cachona    lulu    pepe    federico    copito    dalmata
