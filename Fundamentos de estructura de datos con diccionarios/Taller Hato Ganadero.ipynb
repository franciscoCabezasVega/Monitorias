# %%
import random

def terneros():
    
#----------------------DECLARANDO VARIABLES----------------------#  
    
    inicial = []
    final = []
    
    acuI = 0
    acuF = 0
    
    cantidadI = 0 
    cantidadF = 0
    
    pesoMachoI = 0
    pesoHembraI = 0
    
    pesoMachoF = 0
    pesoHembraF = 0
    
    macho = 0
    hembra = 0
    
#----------------------LLENAR CAMPOS CON NUMEROS ALEATORIOS-----#    

    for x in range (25):
        
        aleatorioI = random.randint(170,180)
        inicial.append(aleatorioI) 
        
        aleatorioF = random.randint(470,490)
        final.append(aleatorioF) 

#-------DELARANDO EL DICCIONARIO Y SUS RESPECTIVAS CLAVES-------#    

    ganado = {
              "Nombre De La Res" : ["luna","luis","ramiro","margarita","lisa",
                                    "clarabell","melisa","toridio","carmen","munina",
                                    "clarita","carlos","camilo","nero","china",
                                    "juana","lola","mauricio","victor","toto",
                                    "gilberto", "timon", "juno", "alex", "thannos",
                                    "gustavo", "gloria", "vilma", "tania", "rosio"
                                   ],
              
              "Sexo De La Res" : [2,1,1,2,2,2,2,1,2,2,2,1,1,1,2,2,2,1,1,1,1,1,2,1,1,1,2,2,2,2],
              
              "Peso Inicial De La Res" : inicial,
              
              "Peso Final De La Res" : final           
             }

#---------------------IMPRIMIENDO DICCIONARIO-------------------#    
    
    for key in ganado:
        print(key, ":", ganado[key], "\n")

#-------CALCULANDO PESO PROMEDIO INICIAL MACHO Y HEMBRA---------#          
        
    for x in ganado["Sexo De La Res"]:
        if x == 1: 
            macho += 1
            pesoMachoI += ganado["Peso Inicial De La Res"][x]
        elif x == 2: 
            hembra += 1
            pesoHembraI += ganado["Peso Inicial De La Res"][x]
    
    pesoPromedioInicialMacho = pesoMachoI / macho
    pesoPromedioInicialHembra = pesoHembraI / hembra
    
#-------CALCULANDO PESO PROMEDIO FINAL MACHO Y HEMBRA-----------#          
    
    for x in ganado["Sexo De La Res"]:
        if x == 1: 
            pesoMachoF += ganado["Peso Final De La Res"][x]
        elif x == 2: 
            pesoHembraF += ganado["Peso Final De La Res"][x]
    
    pesoPromedioFinalMacho = pesoMachoF / macho    
    pesoPromedioFinalHembra = pesoHembraF / hembra

#-------CALCULANDO PESO PROMEDIO FINAL DE TODO EL LOTE----------#          
    
    for x in ganado["Peso Inicial De La Res"]:
        
        acuI += x
        
        promedioPesoInicial = acuI / len(inicial)
        
    for y in ganado["Peso Final De La Res"]:
        
        acuF += y
            
        promedioPesoFinal = acuF / len(final)

#---------------------RESPUESTAS AL TALLER----------------------#          
        
    print("+--------------+")
    print("|Respuestas N°1|")
    print("+--------------+\n")
    
    print(f"El Peso Promedio Inicial de los machos es {pesoPromedioInicialMacho} Kg\n")
    print(f"El Peso Promedio Inicial de las hembras es {pesoPromedioInicialHembra} Kg\n")
    
    print(f"El Peso Promedio Final de los machos es {pesoPromedioFinalMacho} Kg\n")
    print(f"El Peso Promedio Final de las hembras es {pesoPromedioFinalHembra} Kg\n")
    
    print(f"El Peso Promedio Inicial de todo el lote es {promedioPesoInicial} Kg\n")
    print(f"El Peso Promedio Final de todo el lote es {promedioPesoFinal} Kg\n")

#---------------------------------------------------------------#          
    
    nombrePesoInferior = []
    
    for x in range(len(ganado["Peso Final De La Res"])):
        if ganado["Peso Final De La Res"][x] < promedioPesoFinal:
            nombrePesoInferior.append(ganado["Nombre De La Res"][x])    
        
#---------------------------------------------------------------#          
        
    print("+--------------+")
    print("|Respuestas N°2|")
    print("+--------------+\n")
    
    print(f"Las reses que tienen un peso inferior son:\n{nombrePesoInferior}\n") 
    
#---------------------------------------------------------------#          
    
    porcentajeMayor = []
    
    mayor = 0
    
    for x in range(len(inicial)):
        porcentajeAumento = ( ( ganado["Peso Final De La Res"][x] - ganado["Peso Inicial De La Res"][x] ) / 
                                ganado["Peso Inicial De La Res"][x] ) * 100
        porcentajeMayor.append(porcentajeAumento)
    
    for y in range(len(porcentajeMayor)):
                   if porcentajeMayor[y] > mayor:
                       mayor = porcentajeMayor[y]
                       indice = y
    
    nombre = ganado["Nombre De La Res"][indice]
    
    """
    ganado["Peso Inicial De La Res"]   
    ganado["Peso Final De La Res"]
    ganado["Nombre De La Res"]
    """    
        
#---------------------------------------------------------------#          
        
    print("+--------------+")
    print("|Respuestas N°3|")
    print("+--------------+\n")
    print(porcentajeMayor)
    print(f"El ternero que tuvo mayor porcentaje de aumento fue {nombre} con el {round(max(porcentajeMayor))}%\n")

#---------------------------------------------------------------# 
    
    cPaso = 0
    
    for x in ganado["Peso Final De La Res"]:
        if x > 480:
            cPaso += 1
            
    efectividad = ( cPaso / len(inicial) ) * 100
        
#---------------------------------------------------------------#          
        
    print("+--------------+")
    print("|Respuestas N°4|")
    print("+--------------+\n")
    
    print(f"El porcentaje de efectividad fue del {round(efectividad)} %")
    
    
#---------------------------------------------------------------# 
    
terneros()
# Out:
# Nombre De La Res : ['luna', 'luis', 'ramiro', 'margarita', 'lisa', 'clarabell', 'melisa', 'toridio', 'carmen', 'munina', 'clarita', 'carlos', 'camilo', 'nero', 'china', 'juana', 'lola', 'mauricio', 'victor', 'toto', 'gilberto', 'timon', 'juno', 'alex', 'thannos', 'gustavo', 'gloria', 'vilma', 'tania', 'rosio']
#
# Sexo De La Res : [2, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 2]
#
# Peso Inicial De La Res : [170, 176, 173, 176, 179, 180, 176, 170, 171, 176, 178, 170, 174, 172, 174, 180, 178, 179, 177, 177, 172, 176, 173, 180, 176]
#
# Peso Final De La Res : [472, 485, 472, 478, 490, 473, 473, 470, 487, 489, 487, 485, 481, 473, 485, 471, 488, 485, 476, 487, 481, 486, 482, 472, 471]
#
# +--------------+
# |Respuestas N°1|
# +--------------+
#
# El Peso Promedio Inicial de los machos es 176.0 Kg
#
# El Peso Promedio Inicial de las hembras es 173.0 Kg
#
# El Peso Promedio Final de los machos es 485.0 Kg
#
# ...
