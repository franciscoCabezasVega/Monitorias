# %%
def recaudo():
    
    #continuar = "s"
    #Declarando listas, borrar lo que este dentro solo despues de probar que si funciona
    lista_cedula = [1130853932, 49561881, 1150942102]
    lista_nombre = ["Luis", "Lucia", "luna"]
    lista_sexo = ["m", "f", "f"]
    lista_edad = [25, 50, 30]
    lista_procedencia = [1, 2, 3]
    #Lo de abajo es para llenar las listas elemento por elemento
    """
    while continuar == "s" or continuar == "S":
     
        cedula = int(input("Ingrese cedula: "))
        lista_cedula.append(cedula)
        nombre = str(input("Ingrese nombre del participante: "))
        lista_nombre.append(nombre)
        sexo = str(input("Seleccione su sexo: \n m. Masculino \n f. Femenino\n"))
        lista_sexo.append(sexo)
        edad = int(input("Digite su edad: "))
        lista_edad.append(edad)
        Procedencia = int(input("Por favor seleccione una de las siguientes opciones: \n 1. Alumnos \n 2. Docentes \n 3. Público en General\n"))
        lista_procedencia.append(Procedencia)
        
        continuar = str(input("Presiones s o S para continuar, en caso contrario presione otra tecla: "))
        
        if continuar == "s" or continuar == "S":     
            continue
        else:
            print("El programa ha finalizado exitosamente\n")

    print(lista_cedula)
    print(lista_nombre)
    print(lista_sexo)
    print(lista_edad)
    print(lista_procedencia)
    """
    #Total de alumnos matriculados
    
    alumnos = 0
    
    for x in lista_procedencia:
        if x == 1:
            alumnos += 1
    
    print(f"En total hay {alumnos} alumnos")
    print("")
    
    #Total de docentes matriculados
    
    docentes = 0
    
    for x in lista_procedencia:
        if x == 2:
            docentes += 1
    
    if docentes > 1:        
        print(f"En total hay {docentes} docentes registrados en el curso")
    elif docentes == 1:
        print(f"En total hay 1 docente registrado en el curso")
    else:
        print("NO hay docentes registrados en el curso")
        
    print("")
    
    #Porcentaje de publico general matriculado
    
    general = 0
    
    for x in lista_procedencia:
        if x == 3:
            general += 1
    
    porcentaje = ( general / len(lista_procedencia) ) * 100
    
    print(f"En total hay un {porcentaje} % del Público en General")
    print("")
    
    lista_procedencia
    
    #Cantidad de mujeres entre 20 y 30 años
    
    mujeres = 0
    
    for x in range(len(lista_sexo)):
        if lista_sexo[x] == "f": #busca la posicion de los elementos f
            if lista_edad[x] >= 20 and lista_edad[x] <= 30: #según la posición anterior dice si el elemento cumple con la condición
                mujeres += 1
    
    if mujeres > 1:        
        print(f"En total hay {mujeres} mujeres entre los 20 y 30 años registradas en el curso")
    elif mujeres == 1:
        print(f"En total hay una mujer entre los 20 y 30 años registradas en el curso")
    else:
        print("NO hay mujeres entre los 20 y 30 años registradas en el curso")
    
    print("")
    
    #Promedio de edad de los matriculados
    
    promedio = round(sum(lista_edad)/len(lista_edad)) #forma facil sin usar libreria para sacar promedio
    
    print(f"El promedio de edad de los matriculados es de: {promedio} años")
    
    #Numero de participantes inscritos
    
    n_participantes = len(lista_nombre) #forma facil sin usar libreria para sacar el numero de personas inscritas
    print("")
    
    print(f"El numero de participantes inscritos en el curso es de: {n_participantes}")
    print("")
    
    total = 0
    
    for x in lista_procedencia:
        if x == 1:
            total += 500000
            
        elif x == 2:
            total += 1000000
            
        elif x == 3:
            total += 2000000
            
        else:
            pass
    
    print( "El curso ha recaudado un total de: {:,.0f} pesos".format(total) ) #Para imprimir el dinero
        
recaudo()
# Out:
# En total hay 1 alumnos
#
# En total hay 1 docente registrado en el curso
#
# En total hay un 33.33333333333333 % del Público en General
#
# En total hay una mujer entre los 20 y 30 años registradas en el curso
#
# El promedio de edad de los matriculados es de: 35 años
#
# El numero de participantes inscritos en el curso es de: 3
#
# El curso ha recaudado un total de: 3,500,000 pesos
