# %%
import math

def angry_birds_manual():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad = int(input("Por favor indica una velocidad para probar: "))
            
            distancia_alcanzada = ( ( velocidad * velocidad ) / gravedad ) * math.sin( 2 * math.radians(angulo) )
            
            print("La distancia alcanzada fue de: ", distancia_alcanzada)
            
            if distancia_alcanzada > distancia_objetivo:
                print("Se sobrepasó el objetivo, con una velocidad de", velocidad)
            else:
                print("No se sobrepasó el objetivo, con una velocidad de", velocidad)
            
            print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_manual()

# %%
import math

def angry_birds_for():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad_inicial = int(input("Por favor indica una velocidad inicial para probar: "))
            print("")
            velocidad_final = int(input("Por favor indica una velocidad final de la prueba: "))
            print("")
            
            for velocidad in range(velocidad_inicial,velocidad_final+1,1):
                
                distancia_alcanzada = ( ( velocidad * velocidad ) / gravedad ) * math.sin( 2 * math.radians(angulo) )

                print("La distancia alcanzada fue de: ", distancia_alcanzada)

                if distancia_alcanzada > distancia_objetivo:
                    print("Se sobrepasó el objetivo, con una velocidad de", velocidad)
                else:
                    print("No se sobrepasó el objetivo, con una velocidad de", velocidad)

                print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_for()

# %%
import math

def angry_birds_while():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad_inicial = int(input("Por favor indica una velocidad inicial para probar: "))
            print("")
            velocidad_final = int(input("Por favor indica una velocidad final de la prueba: "))
            print("")
            
            while velocidad_inicial <= velocidad_final:
                                
                distancia_alcanzada = ( ( velocidad_inicial * velocidad_inicial ) / gravedad ) * math.sin( 2 * math.radians(angulo) )

                print("La distancia alcanzada fue de: ", distancia_alcanzada)

                if distancia_alcanzada > distancia_objetivo:
                    print("+---------------------------------------------------------------------+|")
                    print("|Se sobrepasó el objetivo, con una velocidad de", velocidad_inicial, "|")
                    print("+---------------------------------------------------------------------+|")
                else:
                    print("No se sobrepasó el objetivo, con una velocidad de", velocidad_inicial)
                
                velocidad_inicial = velocidad_inicial + 1
                
                print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_while()

# %%
import math

def angry_birds_while_break():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad_inicial = int(input("Por favor indica una velocidad inicial para probar: "))
            print("")
            velocidad_final = int(input("Por favor indica una velocidad final de la prueba: "))
            print("")
            
            while velocidad_inicial <= velocidad_final:
                                
                distancia_alcanzada = ( ( velocidad_inicial * velocidad_inicial ) / gravedad ) * math.sin( 2 * math.radians(angulo) )
                
                print("La distancia alcanzada fue de: ", distancia_alcanzada)
                              
                if distancia_alcanzada > distancia_objetivo:
                    print("")
                    print("Se sobrepasó el objetivo, con una velocidad de", velocidad_inicial) 
                    break
                
                velocidad_inicial = velocidad_inicial + 1
                
            print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_while_break()

# %%
import math

def angry_birds_for_precision():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad_inicial = int(input("Por favor indica una velocidad inicial para probar: "))
            print("")
            velocidad_final = int(input("Por favor indica una velocidad final de la prueba: "))
            print("")
            
            for velocidad in range(velocidad_inicial,velocidad_final+1,1):
                
                print (str( float( velocidad/1000.0 ) ), ", ")
                
                distancia_alcanzada = ( ( velocidad * velocidad ) / gravedad ) * math.sin( 2 * math.radians(angulo) )

                print("La distancia alcanzada fue de: ", distancia_alcanzada)

                if distancia_alcanzada > distancia_objetivo:
                    print("Se sobrepasó el objetivo, con una velocidad de", velocidad)
                else:
                    print("No se sobrepasó el objetivo, con una velocidad de", velocidad)

                print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_for()

# %%
import math

def angry_birds_while_estructuras_selectivas():
    
    #Definiendo variables
    distancia_objetivo = 503
    distancia_alcanzada = 0
    gravedad = 9.8
    angulo = 45
    velocidad_inicial = 0
    velocidad_final = 0
    velocidad = 0
    
    continuar = True
    
    while continuar:
        
        continuar = input("Desea continuar? s/n: ")
        print("")
        
        if continuar == "s":
            
            velocidad_inicial = int(input("Por favor indica una velocidad inicial para probar: "))
            print("")
            velocidad_final = int(input("Por favor indica una velocidad final de la prueba: "))
            print("")
            
            while velocidad_inicial <= velocidad_final:
                                
                distancia_alcanzada = ( ( velocidad_inicial * velocidad_inicial ) / gravedad ) * math.sin( 2 * math.radians(angulo) )

                print("La distancia alcanzada fue de: ", distancia_alcanzada)

                if distancia_alcanzada > distancia_objetivo:
                    print("Se sobrepasó el objetivo, con una velocidad de", velocidad_inicial)
                elif distancia_alcanzada == distancia_objetivo:
                    print("Se Alcanzó el objetivo, con una velocidad de", velocidad_inicial)
                else:
                    print("No se sobrepasó el objetivo")
                
                velocidad_inicial = velocidad_inicial + 1
                
                print("")
            continue
            
        elif continuar == "n": 
            
            print("Hasta luego!!")
            print("")
            break
            
        else:
            print("La opción digitada no es valida, Por favor intente nuevamente")
            print("")
    
angry_birds_while_estructuras_selectivas()
